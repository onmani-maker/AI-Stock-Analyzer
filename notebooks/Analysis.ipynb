# %% [markdown]
# # AI Stock Analyzer
#
# Starter notebook for exploring stock prices, options data, technical indicators, and AI-generated reports.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT / 'src'))

from stock_analysis import fetch_stock_history, summarize_stock
from indicators import add_technical_indicators

# %%
ticker = 'AAPL'
history = fetch_stock_history(ticker)
analysis = add_technical_indicators(history)
summarize_stock(ticker, analysis)
